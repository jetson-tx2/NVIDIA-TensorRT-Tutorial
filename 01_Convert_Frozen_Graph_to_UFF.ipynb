# %%
# !nvidia-smi
# Out:
# Thu Feb  7 00:08:49 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.25       Driver Version: 418.25       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM3...  On   | 00000000:34:00.0 Off |                    0 |
# | N/A   32C    P0    52W / 350W |      0MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM3...  On   | 00000000:36:00.0 Off |                    0 |
# | N/A   32C    P0    52W / 350W |      0MiB / 32480MiB |      0%      Default |
# ...

# %%
# !convert-to-uff /datasets/retail/iva/industrial-inspection/pg-defect-segmentation/models/artifacts/frozen_graph.pb \
  -o /datasets/retail/iva/industrial-inspection/pg-defect-segmentation/models/artifacts/frozen_graph.uff
# Out:
# Loading /datasets/retail/iva/industrial-inspection/pg-defect-segmentation/models/artifacts/frozen_graph.pb
# WARNING:tensorflow:From /usr/lib/python3.5/dist-packages/uff/converters/tensorflow/conversion_helpers.py:185: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# UFF Version 0.5.5
# === Automatically deduced input nodes ===
# [name: "input_1"
# op: "Placeholder"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: -1
#       }
#       dim {
#         size: 512
#       }
#       dim {
#         size: 512
#       }
#       dim {
#         size: 3
#       }
#     }
#   }
# }
# ]
# ...
#
# === Automatically deduced output nodes ===
# [name: "conv2d_19/Sigmoid"
# op: "Sigmoid"
# input: "conv2d_19/BiasAdd"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# ]
# ...
#
# ...
